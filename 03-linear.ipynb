# %% [markdown]
# # Most impportant
# # linear function

# %% [markdown]
# ## TORCH.NN
#
# These are the basic building blocks for graphs:
#
# torch.nn
#
# · Containers
#
# . Convolution Layers
#
# . Pooling layers
#
# . Padding Layers
#
# · Non-linear Activations (weighted sum, nonlinearity)
#
# · Non-linear Activations (other)
#
# · Normalization Layers
#
# . Recurrent Layers
#
# · Transformer Layers
#
# . Linear Layers
#
# . Dropout Layers
#
# . Sparse Layers
#
# . Distance Functions
#
# · Loss Functions
#
# · Vision Layers
#
# . Shuffle Layers
#
# · DataParallel Layers (multi-GPU, distributed)
#
# . Utilities
#
# · Quantized Functions
#
# · Lazy Modules Initialization

# %%
import torch
import torch.nn as nn
from neural_network_draw import *
sample = torch.tensor([10.,10.,10.])
linear = nn.Linear(3, 3, bias=False)
print(linear)
print(linear(sample))
# Out:
# Linear(in_features=3, out_features=3, bias=False)
# tensor([-4.3852,  7.6452,  5.4080], grad_fn=<SqueezeBackward4>)

# %% [markdown]
# # linear = nn.Linear(3, 3, bias=False)
#
# 3 is the input dimension, 3 is the output dimension, bias=False means we don't want to add a bias term to the output.

# %%
network = DrawNN([3,3])
network.draw()

# %%
network = DrawNN([2,4,3,1])
network.draw()
# Transformation of:
# 2 -> 4
# 4 -> 3
# 3 -> 1

# %%
import torch.nn as nn
sample = torch.tensor([10.,10.,10.])
linear = nn.Linear(3, 3, bias=False)
print(linear(sample), "\n")
# Out:
# tensor([  2.6889, -11.1008,   5.8332], grad_fn=<SqueezeBackward4>)

# %%
import torch.nn as nn
sample = torch.tensor([10.,10.,10.])
linear = nn.Linear(3, 3, bias=False)
print(linear(sample), "\n")
print(linear.weight, "\n")
print(torch.matmul(linear.weight, sample), "\n")
print(linear(sample), "\n")
# Out:
# tensor([ -5.3635, -12.4560,   2.2466], grad_fn=<SqueezeBackward4>)
#
# Parameter containing:
# tensor([[-0.0924, -0.0442, -0.3998],
#         [-0.3342, -0.4243, -0.4871],
#         [ 0.2056, -0.1062,  0.1252]], requires_grad=True)
#
# tensor([ -5.3635, -12.4560,   2.2466], grad_fn=<MvBackward0>)
#
# tensor([ -5.3635, -12.4560,   2.2466], grad_fn=<SqueezeBackward4>)

# %%
import torch.nn.functional as F

# Create a tensor
tensor1 = torch.tensor([1.0, 2.0, 3.0])

# Apply softmax using torch.nn.functional.softmax()
softmax_output = F.softmax(tensor1, dim=0)

print(softmax_output)
# Out:
# tensor([0.0900, 0.2447, 0.6652])

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# torch.nn.Linear(in_features = 3, out_features = 1, bias=True)
#
# # formula = y = xW^T + b
#
# ## y = output
# ## x = input
# ## W = weight
# ## b = bias
# ## T = transpose
