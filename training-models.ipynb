# %%
import torch
with open('wizard_of_oz.txt', 'r', encoding='utf-8') as f: # short for file
    text = f.read()
#tokenization
# string_to_int = {}
# for index, character in enumerate(chars):
#     string_to_int[character] = index

# def encode(text):
#     encoded_list = []
#     for character in text:
#         encoded_list.append(string_to_int[character])
#     return encoded_list


chars = sorted(set(text))
string_to_int = { ch:i for i,ch in enumerate(chars) }
encode = lambda s: [string_to_int[c] for c in s] # from string  to list of integers



data = torch.tensor(encode(text), dtype=torch.long)
print(data[:100])
